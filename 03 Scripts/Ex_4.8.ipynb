# %% [markdown]
# # 4.8: Grouping Data & Aggregating Variables

# %% [markdown]
# ## This script contains the following:
# ### 1. creating a subset of the data
# ### 2. using group by function
# ### 3. aggregating data with transform function
# ### 4. exporting dataframe

# %% [markdown]
# ### 1. creating a subset of the data

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#import orders_products_combined dataset as df_ords_prods_merge

# %%
#defining path

# %%
path = r'C:/Users/LocalAdmin/Instacart Basket Analysis'

# %%
path
# Out:
# 'C:/Users/LocalAdmin/Instacart Basket Analysis'

# %%
#importing orders_products_combined using path

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# ...

# %%
#create a subset called df of the first one million entries

# %%
df = df_ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# ...

# %% [markdown]
# ### 2. using group by function

# %%
# Grouping data with pandas using 'groupby' function

# %%
##step 1:Split the data into groups based on some criteria.

# %%
df.groupby('product_name')

# %%
##step 2: aggregate the data with agg

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.562844
# 2                17.518895
# 3                16.907152
# 4                17.537934
# 5                14.894521
# 6                16.658449
# 7                17.072954
# 8                14.942021
# 9                15.447580
# 10               18.681852
# 11               15.352278
# 12               14.327957
# 13               16.578690
# 14               16.666369
# 15               16.153766
# 16               17.768070
# 17               15.602964
# 18               19.674252
# 19               16.924344
# 20               16.292631
# 21               25.535596

# %%
#Using mean instead of agg

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.562844
# 2     17.518895
# 3     16.907152
# 4     17.537934
# 5     14.894521
# 6     16.658449
# 7     17.072954
# 8     14.942021
# 9     15.447580
# 10    18.681852
# 11    15.352278
# 12    14.327957
# 13    16.578690
# 14    16.666369
# 15    16.153766
# 16    17.768070
# 17    15.602964
# 18    19.674252
# 19    16.924344
# 20    16.292631
# 21    25.535596
# Name: order_number, dtype: float64

# %%
# performing multiple aggregations. defining the mini and maxi in the order number column

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.562844   1  99
# 2                17.518895   1  96
# 3                16.907152   1  99
# 4                17.537934   1  99
# 5                14.894521   1  99
# 6                16.658449   1  99
# 7                17.072954   1  99
# 8                14.942021   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.352278   1  99
# 12               14.327957   1  99
# 13               16.578690   1  99
# 14               16.666369   1  99
# 15               16.153766   1  99
# 16               17.768070   1  99
# 17               15.602964   1  99
# 18               19.674252   1  99
# 19               16.924344   1  99
# 20               16.292631   1  99
# 21               25.535596   1  98

# %% [markdown]
# ### 3. Aggregating data with transform function

# %%
#creating flags for customer loyalty using the following criteria
#If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
#If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.”
#If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

# %%
#Steps to achieve this
#Split the data into groups based on the “user_id” column.
#Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
#Create a new column, “max_order,” into which you’ll place the results of your aggregation.

# %%
#all three steps can be included in a single line of code:
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\LocalAdmin\AppData\Local\Temp\ipykernel_18592\1076893930.py:2: FutureWarning: The provided callable <function max at 0x000001E01D6896C0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#checking new column
df_ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %%
#deriving columns with loc for loyalty flags

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check loyalty flags
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: count, dtype: int64

# %%
#cross-checking loyalty flags

# %%
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number','max_order']].head(60)
# Out:
#     user_id      loyalty_flag  order_number  max_order
# 0       138  Regular customer            28         32
# 1       138  Regular customer            30         32
# 2       709      New customer             2          5
# 3       764      New customer             1          3
# 4       764      New customer             3          3
# 5       777  Regular customer            16         26
# 6       825      New customer             3          9
# 7       910  Regular customer            12         12
# 8      1052  Regular customer            10         20
# 9      1052  Regular customer            15         20
# 10     1379      New customer             1         10
# 11     1480    Loyal customer            36         43
# 12     1480    Loyal customer            38         43
# 13     1480    Loyal customer            39         43
# 14     1494  Regular customer             6         13
# 15     1494  Regular customer             7         13
# ...

# %% [markdown]
# ### 4. exporting the dataframe with new columns

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'aggregated_ords_prods_merge.pkl'))
