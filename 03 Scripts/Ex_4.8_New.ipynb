# %% [markdown]
# # 4.8: Grouping Data & Aggregating Variables

# %% [markdown]
# ## This script contains the following:
# ### 1. importing libraries and datasets
# ### 2. aggregating
# ### 3. use group by and transform
# ### 4. using loc function
# ### 5. group by and agg function
# ### 6. creating flags
# ### 7. exporting dataframe

# %% [markdown]
# ### 1. importing libraries and datasets

# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Import ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise

# %%
# defining the path

# %%
path = r'C:/Users/LocalAdmin/Instacart Basket Analysis'

# %%
#importing the ords_prods_merge dataframe

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'aggregated_ords_prods_merge.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# ...

# %% [markdown]
# ### 2. aggregating

# %%
#Question: ou learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457687
# 2                17.277920
# 3                17.179756
# 4                17.811403
# 5                15.213779
# 6                16.439806
# 7                17.225773
# 8                15.340520
# 9                15.895474
# 10               20.197148
# 11               16.170828
# 12               15.887622
# 13               16.583304
# 14               16.757377
# 15               16.165037
# 16               17.663250
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
# Question: Analyze the result. How do the results for the entire dataframe differ from those of the subset?

# %% [markdown]
# Most the averages are approximately the same althrough there are instances where mean for the full data is highere than that for the sample of 1 million first observations.

# %% [markdown]
# ### 3. using group by and transform

# %%
# Question:Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
# Use groupby and transform() functions with np.max argument to determine maximum order number for each user
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\LocalAdmin\AppData\Local\Temp\ipykernel_1132\1602908596.py:2: FutureWarning: The provided callable <function max at 0x000001C58E539620> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#Viewing the updated dataframe

# %%
ords_prods_merge.head(30)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %% [markdown]
# ### 4. using loc function

# %%
# adopting 'loc' to create loyalty flags

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# checking the counts of loyalty flags

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: count, dtype: int64

# %%
# Viewing the dataframe to see how it looks

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# ...

# %% [markdown]
# ### 5. group by and agg functions

# %%
#Question: The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. 
#Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). 
#What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
# Using 'groupby' and 'agg' to determine if there is a difference in spending habits of different loyalty groups

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.388747  1.0  99999.0
# New customer      13.294370  1.0  99999.0
# Regular customer  12.496203  1.0  99999.0

# %% [markdown]
# Indeed, there is a difference in the mean price for goods bought by loyal, new and regular customers. However, the minimum for all loyalty groups is 1 whilst the maximum price is 9999.0

# %% [markdown]
# ### 6. creating flags

# %% [markdown]
# ##### The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria: Iff the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# Using the transform function to get the average price for purchases by each user

# %%
ords_prods_merge['mean_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\LocalAdmin\AppData\Local\Temp\ipykernel_1132\72723565.py:1: FutureWarning: The provided callable <function mean at 0x000001C58E53A020> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['mean_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# viewing the 'user_id' and 'prices'

# %%
ords_prods_merge[['user_id', 'mean_product_price']].head(30)
# Out:
#     user_id  mean_product_price
# 0       138            6.935811
# 1       138            6.935811
# 2       709            7.930208
# 3       764            4.972414
# 4       764            4.972414
# 5       777            6.935398
# 6       825            5.957576
# 7       910            6.680000
# 8      1052            7.162500
# 9      1052            7.162500
# 10     1379            5.813636
# 11     1480            5.139394
# 12     1480            5.139394
# 13     1480            5.139394
# 14     1494            6.803797
# 15     1494            6.803797
# 16     1494            6.803797
# 17     1540            6.607122
# 18     1540            6.607122
# 19     1540            6.607122
# 20     1540            6.607122
# 21     1540            6.607122
# 22     1540            6.607122
# 23     1540            6.607122
# 24     1540            6.607122
# 25     1540            6.607122
# 26     1540            6.607122
# 27     1540            6.607122
# ...

# %%
# creation of spending flag using the loc function

# %%
ords_prods_merge.loc[ords_prods_merge['mean_product_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
#Viewing the counts of each spending flag

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31798751
# High spender      635461
# Name: count, dtype: int64

# %%
# Checking the head

# %%
ords_prods_merge[['user_id', 'mean_product_price', 'spending_flag']].head(30)
# Out:
#     user_id  mean_product_price spending_flag
# 0       138            6.935811   Low spender
# 1       138            6.935811   Low spender
# 2       709            7.930208   Low spender
# 3       764            4.972414   Low spender
# 4       764            4.972414   Low spender
# 5       777            6.935398   Low spender
# 6       825            5.957576   Low spender
# 7       910            6.680000   Low spender
# 8      1052            7.162500   Low spender
# 9      1052            7.162500   Low spender
# 10     1379            5.813636   Low spender
# 11     1480            5.139394   Low spender
# 12     1480            5.139394   Low spender
# 13     1480            5.139394   Low spender
# 14     1494            6.803797   Low spender
# 15     1494            6.803797   Low spender
# 16     1494            6.803797   Low spender
# 17     1540            6.607122   Low spender
# 18     1540            6.607122   Low spender
# ...

# %% [markdown]
# #### Question 7

# %% [markdown]
# #### In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer”
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# I use groupby 'user_id' and proceed to define the median number of days between orders for each user
ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\LocalAdmin\AppData\Local\Temp\ipykernel_1132\3077471149.py:2: FutureWarning: The provided callable <function median at 0x000001C58E668EA0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Viewing how the created columns look

# %%
ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders']].head(10)
# Out:
#    user_id  days_since_prior_order  median_days_between_orders
# 0      138                     3.0                         8.0
# 1      138                    20.0                         8.0
# 2      709                     6.0                         8.0
# 3      764                     NaN                         9.0
# 4      764                     9.0                         9.0
# 5      777                    26.0                        11.0
# 6      825                    30.0                        20.0
# 7      910                    30.0                         6.0
# 8     1052                    19.0                        10.0
# 9     1052                    15.0                        10.0

# %%
# Apply the loc function to create flags

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] > 20, 'order_frequency'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_between_orders'] <= 20) & (ords_prods_merge['median_days_between_orders'] > 10), 'order_frequency'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] <= 10, 'order_frequency'] = 'Frequent customer'

# %%
# checking the frequencies for the different flags

# %%
ords_prods_merge['order_frequency'].value_counts(dropna = False)
# Out:
# order_frequency
# Frequent customer        21577409
# Regular customer          7217134
# Non-frequent customer     3639669
# Name: count, dtype: int64

# %% [markdown]
# ### 7. exporting the dataframe

# %%
# Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.
# I name the exported dataframe 'ords_prods_new

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_new.pkl'))
